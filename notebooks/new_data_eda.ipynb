# %%
import pandas as pd

# %%
df = pd.read_csv('../data/lox_dpph_regression_pchembl.csv')

# %%
df.head()
# Out:
#           Title  pchembl  First Zagreb  \
# 0   CHEMBL27410      4.0            70
# 1  CHEMBL464006      4.0           172
# 2  CHEMBL164332      4.0            98
# 3  CHEMBL164332      4.0            98
# 4  CHEMBL164332      4.0            98
#
#    First Zagreb index by valence vertex degrees  Second Zagreb  \
# 0                                       173.605             80
# 1                                       462.000            207
# 2                                       175.000            103
# 3                                       175.000            103
# 4                                       175.000            103
#
#    Second Zagreb index by valence vertex degrees  Polarity  \
# 0                                        176.111        19
# 1                                        480.000        57
# 2                                        147.000        21
# 3                                        147.000        21
# ...

# %%
with open('../results/dtypes.txt', 'w') as f:
    f.write(str(list(df.dtypes)))

# %%
import matplotlib.pyplot as plt

# %%
y = df['pchembl']
plt.hist(y)
# Out:
# (array([ 208.,  532., 1688., 1912., 1855., 1531., 1110.,  975.,  600.,
#          185.]),
#  array([4.   , 4.552, 5.104, 5.656, 6.208, 6.76 , 7.312, 7.864, 8.416,
#         8.968, 9.52 ]),
#  <BarContainer object of 10 artists>)
