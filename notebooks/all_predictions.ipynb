# %%
import pandas as pd
import numpy as np

import lazypredict
from lazypredict.Supervised import LazyRegressor

from functions import *

from sklearn import svm, preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, KFold, cross_val_score

# %%
df_train_LOX = pd.read_csv('../data/training_set_LOX.csv')
df_train_ANT = pd.read_csv('../data/training_set_antioxidant.csv')
df_test = pd.read_csv('../data/test_set.csv')

#drop title column
df_train_LOX = df_train_LOX.drop(columns = ['Title'], axis = 1)
df_train_ANT = df_train_ANT.drop(columns = ['Title'], axis = 1)
df_test = df_test.drop(columns = ['Title'], axis = 1)

# %%
#replace NaN values in each file with mean of column

mean_values_LOX = df_train_LOX.mean()
mean_values_ANT = df_train_ANT.mean()

df_train_LOX = df_train_LOX.fillna(mean_values_LOX)
df_train_ANT = df_train_ANT.fillna(mean_values_ANT)

#merge LOX and ANT arrays
frames = [df_train_LOX, df_train_ANT]
merged_train = pd.concat(frames)
merged_train.shape

train_set = merged_train

# %%
#normalization
scaler = preprocessing.MinMaxScaler()

cols = train_set.columns
d = scaler.fit_transform(train_set)
train_set = pd.DataFrame(d, columns=cols)

cols = df_test.columns
d = scaler.fit_transform(df_test)
df_test = pd.DataFrame(d, columns=cols)

# %%
#form data for tests
x = train_set.loc[:, train_set.columns != 'class']
y = train_set.iloc[:,0]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
#Run all regression algorithms
clf = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(x_train, x_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [12:49<00:00, 18.33s/it]
#                                                               Adjusted R-Squared  \
# Model
# ExtraTreesRegressor                                                         0.89
# XGBRegressor                                                                0.85
# RandomForestRegressor                                                       0.84
# BaggingRegressor                                                            0.84
# HistGradientBoostingRegressor                                               0.84
# LGBMRegressor                                                               0.84
# KNeighborsRegressor                                                         0.81
# NuSVR                                                                       0.80
# SVR                                                                         0.77
# ExtraTreeRegressor                                                          0.74
# GradientBoostingRegressor                                                   0.72
# MLPRegressor                                                                0.72
# DecisionTreeRegressor                                                       0.71
# LassoLarsIC                                                                 0.52
# TransformedTargetRegressor                                                  0.51
# LinearRegression                                                            0.51
# LassoLarsCV                                                                 0.50
# RidgeCV                                                                     0.48
# BayesianRidge                                                               0.47
# Ridge                                                                       0.47
# LassoCV                                                                     0.45
# ElasticNetCV                                                                0.45
# LinearSVR                                                                   0.34
# HuberRegressor                                                              0.27
# KernelRidge                                                                 0.26
# AdaBoostRegressor                                                           0.20
# GaussianProcessRegressor                                                    0.18
# OrthogonalMatchingPursuit                                                   0.18
# OrthogonalMatchingPursuitCV                                                 0.18
# TweedieRegressor                                                            0.17
# LarsCV                                                                      0.08
# PoissonRegressor                                                            0.02
# ElasticNet                                                                 -0.29
# DummyRegressor                                                             -0.29
# Lasso                                                                      -0.29
# LassoLars                                                                  -0.29
# PassiveAggressiveRegressor                                                 -0.38
# QuantileRegressor                                                          -0.47
# SGDRegressor                                               -11753207527415916.00
# Lars                          -4159446129775089849748364827897219288183512112...
#
#                                                                        R-Squared  \
# Model
# ExtraTreesRegressor                                                         0.91
# XGBRegressor                                                                0.89
# RandomForestRegressor                                                       0.88
# BaggingRegressor                                                            0.88
# HistGradientBoostingRegressor                                               0.87
# LGBMRegressor                                                               0.87
# KNeighborsRegressor                                                         0.85
# NuSVR                                                                       0.85
# SVR                                                                         0.82
# ExtraTreeRegressor                                                          0.80
# GradientBoostingRegressor                                                   0.78
# MLPRegressor                                                                0.78
# DecisionTreeRegressor                                                       0.78
# LassoLarsIC                                                                 0.62
# TransformedTargetRegressor                                                  0.62
# LinearRegression                                                            0.62
# LassoLarsCV                                                                 0.61
# RidgeCV                                                                     0.60
# BayesianRidge                                                               0.59
# Ridge                                                                       0.59
# LassoCV                                                                     0.57
# ElasticNetCV                                                                0.57
# LinearSVR                                                                   0.49
# HuberRegressor                                                              0.44
# KernelRidge                                                                 0.43
# AdaBoostRegressor                                                           0.38
# GaussianProcessRegressor                                                    0.37
# OrthogonalMatchingPursuit                                                   0.36
# OrthogonalMatchingPursuitCV                                                 0.36
# TweedieRegressor                                                            0.36
# LarsCV                                                                      0.28
# PoissonRegressor                                                            0.24
# ElasticNet                                                                 -0.00
# DummyRegressor                                                             -0.00
# Lasso                                                                      -0.00
# LassoLars                                                                  -0.00
# PassiveAggressiveRegressor                                                 -0.07
# QuantileRegressor                                                          -0.14
# SGDRegressor                                                -9125573560431084.00
# Lars                          -3229529601972264722324988157681834839475948443...
#
#                                                                  RMSE  \
# Model
# ExtraTreesRegressor                                              0.10
# XGBRegressor                                                     0.11
# RandomForestRegressor                                            0.11
# BaggingRegressor                                                 0.12
# HistGradientBoostingRegressor                                    0.12
# LGBMRegressor                                                    0.12
# KNeighborsRegressor                                              0.13
# NuSVR                                                            0.13
# SVR                                                              0.14
# ExtraTreeRegressor                                               0.15
# GradientBoostingRegressor                                        0.15
# MLPRegressor                                                     0.15
# DecisionTreeRegressor                                            0.16
# LassoLarsIC                                                      0.20
# TransformedTargetRegressor                                       0.20
# LinearRegression                                                 0.20
# LassoLarsCV                                                      0.20
# RidgeCV                                                          0.21
# BayesianRidge                                                    0.21
# Ridge                                                            0.21
# LassoCV                                                          0.21
# ElasticNetCV                                                     0.21
# LinearSVR                                                        0.23
# HuberRegressor                                                   0.25
# KernelRidge                                                      0.25
# AdaBoostRegressor                                                0.26
# GaussianProcessRegressor                                         0.26
# OrthogonalMatchingPursuit                                        0.26
# OrthogonalMatchingPursuitCV                                      0.26
# TweedieRegressor                                                 0.26
# LarsCV                                                           0.28
# PoissonRegressor                                                 0.29
# ElasticNet                                                       0.33
# DummyRegressor                                                   0.33
# Lasso                                                            0.33
# LassoLars                                                        0.33
# PassiveAggressiveRegressor                                       0.34
# QuantileRegressor                                                0.35
# SGDRegressor                                              31328863.58
# Lars                          589364796479830606778329005572489216.00
#
#                                Time Taken
# Model
# ExtraTreesRegressor                  5.22
# XGBRegressor                         1.26
# RandomForestRegressor               42.64
# BaggingRegressor                     4.43
# HistGradientBoostingRegressor        3.40
# LGBMRegressor                        0.40
# KNeighborsRegressor                  0.15
# NuSVR                                6.20
# SVR                                  0.67
# ExtraTreeRegressor                   0.09
# GradientBoostingRegressor           11.39
# MLPRegressor                         1.08
# DecisionTreeRegressor                0.75
# LassoLarsIC                          0.19
# TransformedTargetRegressor           0.06
# LinearRegression                     0.06
# LassoLarsCV                          0.57
# RidgeCV                              0.10
# BayesianRidge                        0.12
# Ridge                                0.05
# LassoCV                              5.55
# ElasticNetCV                         5.33
# LinearSVR                            1.59
# HuberRegressor                       0.49
# KernelRidge                          0.71
# AdaBoostRegressor                    1.56
# GaussianProcessRegressor             7.18
# OrthogonalMatchingPursuit            0.05
# OrthogonalMatchingPursuitCV          0.14
# TweedieRegressor                     0.05
# LarsCV                               0.53
# PoissonRegressor                     0.05
# ElasticNet                           0.04
# DummyRegressor                       0.03
# Lasso                                0.05
# LassoLars                            0.06
# PassiveAggressiveRegressor           0.09
# QuantileRegressor                  666.34
# SGDRegressor                         0.06
# Lars                                 0.12
